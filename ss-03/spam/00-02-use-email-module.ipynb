# %% [markdown]
# https://docs.python.org/ja/3/library/email.html
#
# を利用してemailを読み込みするのが良さそう

# %%
from email import message_from_file
from email.header import decode_header

# %%
some_file = "./samples/easy_ham/2170.78c282a5e417d6d231dc75aa8588ebb7"

# %%
message = None
with open(some_file, mode="r") as file:
  message = message_from_file(file)

# %%
type(message)
# Out:
# email.message.Message

# %% [markdown]
# ## Headerの処理

# %%
decode_header(message["Content-Type"])
# Out:
# [('text/plain; encoding=utf-8', None)]

# %%
decode_header(message["X-Spam-Level"])
# Out:
# [('', None)]

# %% [markdown]
# Headerを特徴量に利用するとしたらイテレートしたい。
#
# ~~HeaderParserを利用してヘッダーのキーを取得できるのでそちらを利用する~~
# https://docs.python.org/3/library/email.parser.html
#
# `message.Message#items` で取得できるのでそちらでOK

# %%
from email.parser import HeaderParser

headers = None
with open(some_file, mode="r") as file:
  parser = HeaderParser()
  headers = parser.parse(file)

# %%
for h in headers:
  print(h)
# Out:
# Return-Path
# Delivered-To
# Received
# Received
# Received
# Message-Id
# To
# From
# Subject
# Date
# Content-Type
# Lines
# X-Spam-Status
# X-Spam-Level

# %%
message.items()
# Out:
# [('Return-Path', '<rssfeeds@example.com>'),
#  ('Delivered-To', 'yyyy@localhost.example.com'),
#  ('Received',
#   'from localhost (jalapeno [127.0.0.1])\n\tby jmason.org (Postfix) with ESMTP id AE79816F16\n\tfor <jm@localhost>; Mon, 30 Sep 2002 13:43:46 +0100 (IST)'),
#  ('Received',
#   'from jalapeno [127.0.0.1]\n\tby localhost with IMAP (fetchmail-5.9.0)\n\tfor jm@localhost (single-drop); Mon, 30 Sep 2002 13:43:46 +0100 (IST)'),
#  ('Received',
#   'from dogma.slashnull.org (localhost [127.0.0.1]) by\n    dogma.slashnull.org (8.11.6/8.11.6) with ESMTP id g8U81fg21359 for\n    <jm@jmason.org>; Mon, 30 Sep 2002 09:01:41 +0100'),
#  ('Message-Id', '<200209300801.g8U81fg21359@dogma.slashnull.org>'),
#  ('To', 'yyyy@example.com'),
#  ('From', 'gamasutra <rssfeeds@example.com>'),
#  ('Subject', 'Priceless Rubens works stolen in raid on mansion'),
#  ('Date', 'Mon, 30 Sep 2002 08:01:41 -0000'),
#  ('Content-Type', 'text/plain; encoding=utf-8'),
#  ('Lines', '6'),
#  ('X-Spam-Status',
#   'No, hits=-527.4 required=5.0\n\ttests=AWL,DATE_IN_PAST_03_06,T_URI_COUNT_0_1\n\tversion=2.50-cvs'),
#  ('X-Spam-Level', '')]

# %% [markdown]
# ## Body

# %%
message.as_string()
# Out:
# "Return-Path: <rssfeeds@example.com>\nDelivered-To: yyyy@localhost.example.com\nReceived: from localhost (jalapeno [127.0.0.1])\n\tby jmason.org (Postfix) with ESMTP id AE79816F16\n\tfor <jm@localhost>; Mon, 30 Sep 2002 13:43:46 +0100 (IST)\nReceived: from jalapeno [127.0.0.1]\n\tby localhost with IMAP (fetchmail-5.9.0)\n\tfor jm@localhost (single-drop); Mon, 30 Sep 2002 13:43:46 +0100 (IST)\nReceived: from dogma.slashnull.org (localhost [127.0.0.1]) by\n    dogma.slashnull.org (8.11.6/8.11.6) with ESMTP id g8U81fg21359 for\n    <jm@jmason.org>; Mon, 30 Sep 2002 09:01:41 +0100\nMessage-Id: <200209300801.g8U81fg21359@dogma.slashnull.org>\nTo: yyyy@example.com\nFrom: gamasutra <rssfeeds@example.com>\nSubject: Priceless Rubens works stolen in raid on mansion\nDate: Mon, 30 Sep 2002 08:01:41 -0000\nContent-Type: text/plain; encoding=utf-8\nLines: 6\nX-Spam-Status: No, hits=-527.4 required=5.0\n\ttests=AWL,DATE_IN_PAST_03_06,T_URI_COUNT_0_1\n\tversion=2.50-cvs\nX-Spam-Level: \n\nURL: http://www.newsisfree.com/click/-1,8381145,215/\nDate: 2002-09-30T03:04:58+01:00\n\n*Arts:* Fourth art raid on philanthropist's home once targeted by the IRA and \nDublin gangster Martin Cahill.\n\n\n"

# %%
message.get_payload()
# Out:
# "URL: http://www.newsisfree.com/click/-1,8381145,215/\nDate: 2002-09-30T03:04:58+01:00\n\n*Arts:* Fourth art raid on philanthropist's home once targeted by the IRA and \nDublin gangster Martin Cahill.\n\n\n"

# %% [markdown]
# 本文の内容は `get_payload` で取得できる。
#
# しかしX-Spam-Levelの削除により1行空いてしまい、本文開始位置がおかしくなっている。前処理でX-Spam-Levelの後ろの空行を削除しておくべき。

# %%
# !rg "charset"
# Out:
# samples/hard_ham/0002.2fe846db6e3249836abdbfcae459bf2a
# 12:Content-Type: text/html; charset=ISO-8859-1
#
# samples/easy_ham/1079.3d222257b98d7d58a0f970d101be3ad7
# 84:Content-Type: text/plain; charset=us-ascii
#
# samples/spam/0275.0404a07cd99e27d569958716f392082b
# 33:	charset="Windows-1252"
# 89:	charset="iso-8859-1"
# 96:charset=3Diso-8859-1">
#
# samples/spam/0199.955edee89f34960c033c4d1072841356
# 21:Content-Type: text/html; charset="iso-8859-1"
#
# samples/spam/0207.3adcb1a14977a49cac8f6e10f64ac6f7
# 37:Content-Type: text/html; charset="iso-8859-1"
#
# samples/spam/0047.376bd7728ee94b32bc23429d9c51bae5
# 20:Content-Type: text/html; charset="ISO-8859-1"
# 26:<META http-equiv=Content-Type content="text/html; charset=iso-8859-1">
#
# samples/spam/0152.c0ea23686b9ad63dfba6040c1539da71
# 28:Content-Type: text/plain; charset="iso-8859-1"
#
# samples/spam/0430.17440122811305f78e499d2ed0a1fe46
# 23:Content-Type: text/plain; charset="iso-8859-1"
#
# samples/hard_ham/0140.0d1eca4253384df024692c75f8540c4f
# 50:	charset="us-ascii"
# 173:	charset="us-ascii"
# 178:charset=3Dus-ascii">
#
# samples/hard_ham/0115.32aa502e928becbe2db939baa9697928
# 12:Content-Type: text/html; charset=ISO-8859-1
#
# samples/spam/0161.00e60d1a3478f1ae99ff49fbd4b30605
# 29:Content-Type: text/plain; charset="us-ascii"
#
# samples/hard_ham/0027.67c81ed875f5095080aec2de21d50d70
# 12:Content-Type: text/html; charset=ISO-8859-1
#
# samples/hard_ham/0017.24b9a958860c4e29ddf4e58b4dc31c7e
# 12:Content-Type: text/html; charset=ISO-8859-1
#
# samples/spam/0195.8b276e08dd05b0131faa8fb24764f205
# 33:	charset="Windows-1252"
# 92:	charset="iso-8859-1"
# 99:charset=3Diso-8859-1">
#
# samples/spam/0458.8c9d2363547ebaf997282910cf21e95c
# 27:Content-Type: text/plain; charset="ISO-8859-2"
#
# samples/spam/0500.2e8762b67913d1b07bc8da293448d27f
# 26:Content-Type: text/plain; charset="Windows-1252"
#
# samples/easy_ham/1649.00d75963b0db438a7f492b59a5395fc0
# 34:Content-Type: text/plain; charset=ISO-8859-1
#
# samples/easy_ham/0311.de3984f9da9dba841ba515681fa065a6
# 41:Content-Type: text/plain; charset=us-ascii
#
# samples/easy_ham/0579.1220a78a48fabb67052c021782ae7720
# 32:Content-Type: TEXT/PLAIN; charset=US-ASCII
#
# samples/easy_ham/1067.b872a9f6853971d7190007a64d60e381
# 46:Content-Type: text/plain; charset=us-ascii
#
# samples/easy_ham/1140.58310046747fc9cf38a43349d2461870
# 25:Content-Type: text/plain; charset="us-ascii"
#
# samples/easy_ham/1098.0f56b798157b9bd933814ba687e722f1
# 46:Content-Type: text/plain; charset=us-ascii
#
# samples/easy_ham/1312.cb81f191343dc4f26a8a601cf73d790f
# 28:Content-Type: text/plain; charset="iso-8859-1"
#
# samples/easy_ham/
Content-Type: TEXT/PLAIN; charset=US-ASCII
#
# samples/easy_ham/0165.60d0c03c63a588f58ca91b791610e43c
# 46:Content-Type: text/plain; charset=US-ASCII
#
# samples/easy_ham/1190.99eaa82bada000ca0ada9512a3f590e2
# 32:Content-Type: text/plain; charset=US-ASCII
#
# samples/easy_ham/1452.81f3e3d1b40f978cd3c0125e7020dd17
# 27:Content-Type: text/plain; charset="iso-8859-1"
#
# samples/easy_ham/0591.f533bea095d75cc4dc282bdcba69072a
# 31:Content-Type: text/plain; charset=ISO-8859-1; format=flowed
#
# samples/easy_ham/1322.7faaa22a10e2eab022719a868f587686
# 25:Content-Type: text/plain; charset=ISO-8859-1
#
# samples/easy_ham/0725.2c1c01215a3c8c4936f8cfea181092d1
# 31:Content-Type: TEXT/PLAIN; charset=US-ASCII
#
# samples/easy_ham/0286.25aefc468274fe144edb1ee788d6c999
# 40:Content-Type: text/plain; charset=US-ASCII
#
# samples/easy_ham/1199.5ec73158a8a2f5c74523d8eb88871653
# 30:Content-Type: text/plain; charset=US-ASCII
#
# samples/easy_ham/0128.f2500674ec39065ae8a1f643c7100a2b
# 26:Content-Type: text/plain; charset=us-ascii
#
# samples/easy_ham/1192.1d7f09a0119d74789f1918f9c02beb45
# 28:Content-Type: text/plain; charset=US-ASCII
#
# samples/easy_ham/0795.6f8b4da0f06a9c055fc527562fe92330
# 23:Content-Type: text/plain; charset=WINDOWS-1252; format=flowed
#
# samples/easy_ham/0283.469fc9946c6d920af042b022bd63a2f9
# 46:Content-Type: text/plain; charset=US-ASCII
#
# samples/easy_ham/1679.b783b8e80886ae5592280e655058813d
# 37:Content-Type: TEXT/PLAIN; charset=US-ASCII
#
# samples/easy_ham/0684.f0f0e8e9d0c203b93278c58447e3ce88
# 33:Content-Type: text/plain; charset=us-ascii; format=flowed
#
# samples/easy_ham/0466.831f4b97805c8e03cf6630716309e89e
# 27:Content-Type: TEXT/PLAIN; charset=US-ASCII
#
# samples/easy_ham/1112.2e9833f8ba14f5c8fb76c35322ed4a8c
# 39:Content-Type: text/plain; charset=us-ascii
#
# samples/easy_ham/1278.d6395388e0e11e622c6c348603c4ef74
# 29:Content-Type: TEXT/PLAIN; charset=US-ASCII
#
# samples/easy_ham/0425.bc356b284544c185e4ac9e11f4ec1d4a
# 35:Content-Type: text/plain; charset=us-ascii
#
# samples/easy_ham/0123.32e1738c4171dd9d70b727fd7973a291
# 30:Content-Type: text/plain; charset="iso-8859-1"
#
# samples/easy_ham/0400.bc26e5bca8b09db7b496d47715baacad
# 28:Content-Type: text/plain; charset="iso-8859-1"
#
# samples/easy_ham/1720.b17e78a9a5d7145aa8deffc671ace997
# 38:Content-Type: text/plain; charset=us-ascii
#
# samples/easy_ham/0859.c5de7d55c638b365941e5077d598ff6a
# 31:Content-Type: text/plain; charset=us-ascii
#
# samples/easy_ham/0385.86c7c23ec4e9892f6bbfa377760fd303
# 31:Content-Type: text/plain; charset=us-ascii
#
# samples/easy_ham/0405.ef8e0986c113ddf12faa7c1a05ace625
# 35:Content-Type: text/plain; charset=us-ascii
#
# samples/easy_ham/1212.b8a6ce9e2f0d2075ace38710d356c7af
# 83:Content-Type: text/plain; charset=us-ascii
#
# samples/easy_ham/0308.5c3218cf2a6260c6178cbea1b9e345f7
# 27:Content-Type: text/plain; charset=iso-8859-1
#
# samples/easy_ham/1280.542b6637621390bff1378f93bbbc8f6b
# ...
# 15:Content-Type: text/plain; charset=ISO-8859-1
# 38:Content-Type: text/html; charset=ISO-8859-1
#
# samples/easy_ham/0848.ef1b9b43e194c1650d7722ffcc7b20ad
# 30:Content-Type: text/plain; charset=US-ASCII; format=flowed
#
# samples/spam/0311.fad7da9629598eaffeaf6896bdf32d9c
# 36:Content-Type: text/plain; charset="iso-8859-1"
#
# samples/hard_ham/0043.bab3a56e1280de37538e023d2feb1f5b
# 12:Content-Type: text/html; charset=ISO-8859-1
#
# samples/spam/0010.7f5fb525755c45eb78efc18d7c9ea5aa
# 29:Content-Type: text/html; charset=us-ascii
#
# samples/spam/0022.4b5cf3c16feb88dd6932a8c46a41946c
# 27:Content-Type: text/plain; charset="ISO-8859-1"
#
# samples/hard_ham/0153.569daf40165213f3b4116b586362b142
# 31:	charset="iso-8859-1"
# 45:	charset="iso-8859-1"
# 51:charset=3Diso-8859-1">
#
# samples/spam/0007.859c901719011d56f8b652ea071c1f8b
# 23:	charset="iso-8859-1"
#
# samples/easy_ham/0095.b51416f612ac5737e0f4a5529ce453d1
# 22:Content-Type: text/plain; charset="iso-8859-1"
#
# samples/spam/0088.f421d8c380fb0c48483f026d243df9d9
# 30:Content-Type: text/plain; charset=us-ascii
#
# samples/hard_ham/0008.aa277082dc0b40dedc51b2e758a115a9
# 12:Content-Type: text/html; charset=ISO-8859-1
# 19:<META http-equiv=Content-Type content="text/html; charset=windows-1252">
#
# samples/hard_ham/0166.4b3874844ccb78cd7ca2cd03876124b0
# 12:	 charset="us-ascii"
#
# samples/easy_ham/0817.bcee0d97a59953c5e6086df74d4ed665
# 31:Content-Type: text/plain; charset="us-ascii"
#
# samples/spam/0217.2a937e0b9912e1e40dbf17bad6026372
# 25:Content-Type: text/plain; charset=iso-8859-1
# 60:Content-Type: text/html; charset=iso-8859-1
#
# samples/hard_ham/0246.3aa0f2e88ef357632bc485b6bb2b3121
# 19:	charset="iso-8859-1"
#
# samples/hard_ham/0238.7c7d6921e671bbe18ebb5f893cd9bb35
# 23:Content-Type: text/plain; charset=us-ascii
#
# samples/spam/0479.558d7491db4238443bc549ec06021bae
# 32:Content-Type: text/html; charset=iso-8859-1
#
# samples/easy_ham/0153.f78ed3d22e441ab7bd6d006323a83621
# 43:Content-Type: text/plain; charset=US-ASCII
#
# samples/easy_ham/1635.52b59f11291134697f3604f9dfd72080
# 31:Content-Type: TEXT/PLAIN; charset=US-ASCII
#
# samples/spam/0477.c825fdd16a32d2d29f4f3613e412dfb3
# 19:Content-Type: text/plain; charset="ISO-8859-1"
#
# samples/easy_ham/1715.7e47339df52b3d0c131273f1c58ba4eb
# 32:Content-Type: TEXT/PLAIN; charset=US-ASCII
#
# samples/spam/0376.d87b4313e6c43a986060d57a0b8515a6
# 31:Content-Type: text/plain; charset=us-ascii
# 95:Content-Type: text/html; charset=us-ascii
# 99:<META http-equiv=Content-Type content="text/html; charset=iso-8859-1">
#
# samples/easy_ham/0431.26f19fa47fab85e813b1aba8ff6139d6
# 23:Content-Type: text/plain; charset="iso-8859-1"
#
# samples/spam/0456.578afb400f87833c03c4dc2be6fd85bd
# 30:Content-Type: text/plain; charset="iso-8859-1"
#
# samples/easy_ham/0404.eceb4a64a9ef4c1d738782efde23c09b
# 35:Content-Type: text/plain; charset=us-ascii
#
# samples/spam/0314.5b03e0718373f3319eadaec592308aba
# 41:Content-Type: text/html; charset=ISO-8859-1
#
# samples/spam/0454.943161603b1eb6da5187194b5a75186a
# 29:Content-Type: text/html; charset="iso-8859-1"
# 35:<meta http-equiv=3D"Content-Type" content=3D"text/html; charset=3Diso-8859=
#
# samples/spam/0132.7ac2141ed9a163f934ac65b3f59a2a03
# 26:content="text/html; charset=windows-1252"><HTTP-EQUIV="PRAGMA"
#
# samples/spam/0268.1aee52bc302bf1d5c2030229b5dbd63e
# 33:Content-Type: text/plain; charset=iso-8859-1
#
# samples/spam/0375.ad5939ae436ed745d5222893d5ffe191
# 27:Content-Type: text/html; charset="us-ascii"
# 29:<META HTTP-EQUIV="Content-Type" CONTENT="text/html;charset=iso-8859-1">
# 32:<META content="text/html; charset=iso-8859-1" http-equiv=Content-Type>
#
# samples/spam/0282.b9f0c6ac87b24a9abac5f2a564c0a6c6
# 44:Content-Type: text/plain; charset="Windows-1252"
#
# samples/spam/0160.b6b241d37fa9d5f772afca9ef30034c3
# 24:Content-Type: text/plain; charset="us-ascii"
#
# samples/hard_ham/0214.4a88cbb01e5c7f05db4e12180bc122db
# 49:	charset="iso-8859-1"
# 65:	charset="iso-8859-1"
# 70:<META http-equiv=3DContent-Type content=3D"text/html; charset=3Diso-8859-1">
#
# samples/spam/0443.c5581d58a801553fee57b2bfe904ea93
# 15:Content-Type: text/plain; charset="iso-8859-15"
#
# samples/easy_ham/0477.b7958d4d9cb312c16965859705826a7e
# 29:Content-Type: TEXT/PLAIN; charset=US-ASCII
#
# samples/spam/0494.a0865131f55d26362a8efad99c37de01
# 27:Content-Type: text/html; charset="us-ascii"
# 32:<meta http-equiv="Content-Type" content="text/html; charset=iso-8859-1">
#
# samples/spam/0299.9d0b292172cb787eb2ed9e8855222edd
# 26:Content-Type: text/plain; charset=US-ASCII
#
# samples/easy_ham/0145.7400cf6ab4cfe5ffeaab582c9730c656
# 29:Content-Type: text/plain; charset=us-ascii
#
# samples/hard_ham/0248.0e24cff47672d14846badc564585a93e
# 18:Content-Type: text/plain; charset="iso-8859-1"
#
# samples/easy_ham/0225.80a615200726ed2da1bfd347dcfd648c
# 42:Content-Type: text/plain; charset=ISO-8859-1
#
# samples/spam/0065.18d2edcf9aa0e940651b5fdd218ac019
# 33:Content-Type: text/html; charset="iso-8859-1"
#
# samples/spam/0446.d971f234fa00ed94e18f5ce8f5c0f852
# 30:Content-Type: text/plain; charset="ISO-8859-1"
# 94:Content-Type: text/html; charset="ISO-8859-1"
# 102:<meta http-equiv=3D"Content-Type" content=3D"text/html; charset=3Dwindows-1252">
#
# samples/spam/0247.aee6d7984b3dab9a6b0eed524e7a3686
# 31:Content-Type: text/html;charset="iso-8859-1"
#
# samples/hard_ham/0014.97d87718c6480f977d58fc65d985ca7e
# 12:Content-Type: text/html; charset=ISO-8859-1
#
# samples/spam/0099.c4ff6dba0a5177d3c7d8ef54c8920496
# 29:Content-Type: text/html; charset="iso-8859-1"
#
# samples/easy_ham/0289.cb9c0595bddae2c25357ce5c9fbaf687
# 33:Content-Type: text/plain; charset="windows-1251"
#
# samples/spam/0328.cccf842e57907e25d1584cad03f8d2cb
# 15:Content-Type: text/plain; charset=us-ascii
#
# samples/spam/0018.259154a52bc55dcae491cfded60a5cd2
# 23:	charset="iso-8859-1"
#
# samples/hard_ham/0060.a19a223f84a35ed42e2f297c18e25a01
# 12:Content-Type: text/html; charset=ISO-8859-1
#
# samples/spam/0054.839a9c0a07f13718570da944986a898a
# 18:Content-Type: text/plain; charset="iso-8859-1"
#
# samples/easy_ham/0821.479ffdea3cc5f259f453afe16dd27e4a
# 27:Content-Type: text/plain; charset="US-ASCII"
#
# samples/spam/0081.3309521659461b743e1bfc3dc688a5f1
# 31:Content-Type: text/html; charset="iso-8859-1"
#
# samples/spam/0276.7e2fed586e292a7ad8cde7cb095a2601
# 47:Content-Type: text/html; charset="iso-8859-1"
#
# samples/easy_ham/1707.5c6277e057c0b3238b03d60de3109e8e
# 30:Content-Type: text/plain; charset=us-ascii
#
# samples/spam/0439.2c6d4d3e8b817c5315a1c61e4eeb7ee9
# 22:Content-Type: text/plain; charset="iso-8859-1"
#
# samples/spam/0259.7ebf3c0fd752bce5b8056e9454d2c76f
# 26:Content-Type: text/plain; charset="Windows-1252"
#
# samples/spam/0184.a2109736d2f15cde3747a6f335c6f24c
# 24:Content-Type: text/html; charset="iso-8859-1"
#
# samples/spam/0326.80f15e07265a22b78068bab5b56b01c7
# 29:Content-Type: text/plain; charset="iso-8859-1"
#
# samples/spam/0213.5f17fdf863726d4704840f86f698d10b
# 33:Content-Type: text/html; charset="iso-8859-1"
#
# samples/spam/0388.23ff533336b63fb45d267b8cbe59b7b4
# 31:Content-Type: text/plain; charset="Windows-1252"
#
# samples/spam/0149.3300ef4537e1f6accd4489125bef5b0d
# 26:Content-Type: text/plain; charset="iso-8859-1"
#
# samples/spam/0332.b82bddb316d2e12418d6ea8791ce5896
# 28:<meta http-equiv=3D"Content-Type" content=3D"text/html; charset=3Dgb2312">
#
# samples/spam/0482.d2338d94e40e6028a89c0a197ed7c470
# 31:Content-Type: text/html; charset=us-ascii
#
# samples/easy_ham/0771.56f1377225cfa1461304bce68e892600
# 31:Content-Type: text/plain; charset=us-ascii; format=flowed
#
# samples/easy_ham/0854.6fc80acdb73b0ab60c3f316f646c0546
# 30:Content-Type: text/plain; charset=US-ASCII
#
# samples/spam/0204.33e3cd4e0ad791304e554bb259bda53e
# 30:Content-Type: text/html; charset="iso-8859-1"
#
# samples/easy_ham/0298.fb2fe4458efbd24753b011bf6db2deab
# 47:Content-Type: text/plain; charset=US-ASCII
#
# samples/spam/0369.2530542de47d461ccb925fcafc6f0ad5
# 28:Content-Type: text/plain; charset="iso-8859-1"
#
# samples/easy_ham/0435.7d06c898a16be4efbfbdef62c347ab59
# 30:Content-Type: TEXT/PLAIN; charset=US-ASCII
#
# samples/spam/0009.c05e264fbf18783099b53dbc9a9aacda
# 23:Content-type: text/plain; charset=US-ASCII
#
# samples/easy_ham/1197.d2b11de4c8eb13e1fcc1d444665d0d1c
# 29:Content-Type: text/plain; charset=US-ASCII
#
# samples/spam/0121.772c3ccd1b6c1a2e0e2ec0356082c77b
# 22:Content-Type: text/html; charset="us-ascii"
#
# samples/easy_ham/1496.c48399a0c3abb60acd00322bdbb97565
# 64:Content-Type: text/plain; charset=us-ascii
#
# samples/spam/0266.99e95dc7251843f7a2015cb602775694
# 33:	charset=iso-8859-1
#
# samples/spam/0345.b8ba4d6a115368132d1d580c4c9e0307
# 30:	charset="iso-8859-1"
#
# samples/easy_ham/0154.9e065ee6214360e43b9873e39880159e
# 47:Content-Type: text/plain; charset=US-ASCII
#
# samples/spam/0023.4299adbda55862876440ecbc2fce6a67
# 24:Content-Type: text/plain; charset="us-ascii"
#
# samples/spam/0413.4c74110f6640067c2172a04543dea670
# 31:Content-Type: text/html; charset="iso-8859-1"
# 40:<meta http-equiv=3D"Content-Type" content=3D"text/html; charset=3Dwindows-=
#
# samples/spam/0474.81ea7ec9e00168efe6bb824d08825ef3
# 28:Content-Type: text/plain; charset=us-ascii
#
# samples/easy_ham/0045.910fa2e79f96c646f1b6c987c65cbe3f
# 28:Content-Type: text/plain; charset="US-ASCII"
#
# samples/spam/0438.77cb3de3ddbb68012f0dbe370c4e71dc
# 20:Content-Type: text/plain; charset="iso-8859-1"
#
# samples/easy_ham/0250.21660c434f8535865d04d112f8105708
# 31:Content-Type: text/plain; charset=us-ascii
#
# samples/spam/0239.43b3279a300a122610f91725bb92a538
# 23:Content-Type: text/plain; charset="koi8-r"
#
# samples/easy_ham/0197.59ea60c031993abdccb762f9dbb35340
# 42:Content-Type: text/plain; charset=US-ASCII
#
# samples/hard_ham/0096.35188664501272e51fd054e157bc6e24
# 12:Content-Type: text/html; charset=ISO-8859-1
#
# samples/spam/0417.8e6ff04af5a268d0495259b3f6a24d58
# 46:Content-Type: text/html; charset=ISO-8859-1
#
# samples/spam/0232.0edc8786183135557c0f2da5a4460508
# 33:	charset="Windows-1252"
# 67:	charset="iso-8859-1"
# 74:charset=3Diso-8859-1">
#
# samples/spam/0403.5aa6261d36d1362bcd181ed7738de7f7
# 21:Content-Type: text/plain; charset="us-ascii"
#
# samples/hard_ham/0078.aa6431fbd6f6eb44d9f3964ae28115b3
# 19:Content-Type: text/html; charset=us-ascii
#
# samples/spam/0344.8bbe5c7c8269a039761968a1b10a936a
# 30:	charset="iso-8859-1"
#
# samples/easy_ham/0863.3de076f8a3b5f011d630dbefbd371694
# 31:Content-Type: text/plain; charset="us-ascii"; format=flowed
#
# samples/hard_ham/0033.6a01f21844e78eba1202be887c1d9473
# 12:Content-Type: text/html; charset=ISO-8859-1
#
# samples/spam/0153.eddc658b08a04641a2494ba6b6eb0a3c
# 27:Content-Type: text/html; charset="iso-8859-1"
#
# samples/hard_ham/0052.ae8ff272d7ef31c406cad02f476fefed
# 19:Content-Type: text/html; charset=us-ascii
#
# samples/hard_ham/0099.cbdd0b8a16893d7f13c2b753d5c67844
# 19:Content-Type: text/html; charset=us-ascii
#
# samples/easy_ham/0106.808c5e5ed0b801f667a34ead8221972e
# 29:Content-Type: TEXT/PLAIN; charset=US-ASCII
#
# samples/hard_ham/0135.b09cf763aa3b510180a239fb6e103718
# 19:Content-type: text/plain; charset=US-ASCII
#
# samples/easy_ham/0039.5bf1ec6602c4657bac8d566604572ad5
# 40:Content-Type: text/plain; charset=us-ascii
#
# samples/easy_ham/1453.1089ed990307329cb4527b6835b2259c
# 36:Content-Type: text/plain; charset=us-ascii; format=flowed
#
# samples/hard_ham/0132.2893a03c7ec608a1416bef197a3ac13c
# 29:Content-Type: text/plain; charset=ISO-8859-1
#
# samples/hard_ham/0025.15d4566a6f33d21e7f2fe5c452e1a9fe
# 12:Content-Type: text/html; charset=ISO-8859-1
#
# samples/hard_ham/0235.a4ac9d7b43ea2bbf8dbb763e9160ee95
# 47:Content-Type: text/plain; charset="us-ascii" ; format="flowed"
#
# samples/easy_ham/0775.380d5908cc272338fc163b1d1a748e8c
# 28:Content-Type: text/plain; charset="US-ASCII"
#
# samples/hard_ham/0125.708a97786a1fe270ac3fc8f7a3a533ef
# 15:Content-Type: text/html; charset=ISO-8859-1
#
# samples/spam/0440.16a3caff5b5788f2ae378850041252d7
# 31:Content-Type: text/plain; charset="iso-8859-1"
#
# samples/spam/0230.035bbcbe1235cb6fdd0a5d6d626dc5c4
# 22:Content-Type: text/html; charset="iso-8859-1"
# 27:<META http-equiv=3DContent-Type content=3D"text/html; charset=3Diso-8859-1=
#
# samples/spam/0246.3b997087302d48ff57ab5afb3d400d5b
# 21:Content-Type: text/plain; charset="iso-8859-1"
#
# samples/hard_ham/0150.1a4004bb9fde0616def0888607679f9d
# 18:Content-Type: text/plain; charset="iso-8859-1"
#
# samples/spam/0126.713b324e028cc69213e67ad3d7319f5d
# 22:Content-Type: text/html; charset="iso-8859-1"
#
# samples/hard_ham/0229.603a14ce10e319ac433b686a3f9e9999
# 28:Content-Type: text/plain; charset=us-ascii
#
# samples/spam/0278.229f1cdd03eb4e6ff86e9fd29551f577
# 30:Content-Type: text/html; charset="ISO-8859-9"
#
# samples/spam/0272.97ecf97bd5f1563ac88d9eb4c8a51062
# 89:<META HTTP-EQUIV="Content-Type" CONTENT="text/html;charset=iso-8859-1">
# 92:<META content="text/html; charset=iso-8859-1" http-equiv=Content-Type>
#
# samples/easy_ham/1005.aaca009bb6cf75da8456c570bad6ad08
# 24:Content-Type: text/plain; charset="iso-8859-1"
#
# samples/hard_ham/0007.7f2ea3a532284cff3321e5ba159cdb50
# 15:Content-Type: text/plain; charset=ISO-8859-1
# 38:Content-Type: text/html; charset=ISO-8859-1
#
# samples/easy_ham/0634.2da7e83d50baee90c3c9defd2aa30b72
# 27:Content-Type: text/plain; charset="iso-8859-1"
#
# samples/spam/0392.9e194dfff92f7d9957171b04a8d4b957
# 25:Content-Type: text/plain; charset=US-ASCII
#
# samples/hard_ham/0003.0aa92b5f121c27c6e094fd89c6c89448
# 12:Content-Type: text/plain; charset=ISO-8859-1
#
# samples/easy_ham/1561.b968a0929d29009dbb76603323c1862f
# 32:Content-Type: text/plain; charset="us-ascii"
#
# samples/hard_ham/0013.f35f66ce3e2c580dbb32b105e0f70c7d
# 12:Content-Type: text/html; charset=ISO-8859-1
#
# samples/hard_ham/0009.2bc1d4efa31fc78edb6e4bd82f68023f
# 19:Content-Type: text/html; charset=us-ascii
#
# samples/spam/0146.6656452972931e859e640f6ac57d2962
# 22:Content-Type: text/html; charset="iso-8859-1"
#
# samples/easy_ham/0401.9ab0bcc81e70d6930acfefc2854a0172
# 35:Content-Type: text/plain; charset=us-ascii
#
# samples/spam/0112.ec411d26d1f4decc16af7ef73e69a227
# 33:	charset="Windows-1252"
# 116:	charset="iso-8859-1"
# 123:charset=3Diso-8859-1">
#
# samples/hard_ham/0143.078ced89f2de25e9423f53798e6e3a70
# 44:Content-Type: text/plain; charset=us-ascii
#
# samples/hard_ham/0198.9938b1b97c018592ea6fcec265fb5ef7
# 48:Content-Type: text/plain; charset="us-ascii"
#
# samples/hard_ham/0034.3b223f26d69f641451a5d95faa9cb564
# 19:Content-Type: text/html; charset=us-ascii
#
# samples/spam/0108.4506c2ef846b80b9a7beb90315b22701
# 24:Content-Type: text/html; charset="iso-8859-1"
# 29:<meta http-equiv="Content-Type" content="text/html; charset=iso-8859-1">
#
# samples/hard_ham/0228.651a40f1c0b2ba19122eccebccbae788
# 25:	charset="iso-8859-1"
#
# samples/spam/0125.44381546181fc6c5d7ea59e917f232c5
# 22:	charset="Windows-1252"
#
# samples/spam/0343.0630afbe4ee1ffd0db0ffb81c6de98de
# 30:	charset="iso-8859-1"
#
# samples/easy_ham/1000.348e8a82897b05d584de019f4dd5c7e2
# 27:Content-Type: TEXT/PLAIN; charset=US-ASCII
#
# samples/spam/0395.bb934e8b4c39d5eab38f828a26f760b4
# 35:	charset="Windows-1252"
# 73:	charset="iso-8859-1"
# 80:charset=3Diso-8859-1">
#
# samples/spam/0485.9021367278833179285091e5201f5854
# 27:Content-Type: text/html; charset="us-ascii"
#
# samples/hard_ham/0202.9b71c90c298d453025eae7bbcc46018b
# 32:	charset="iso-8859-1"
# 471:	charset="iso-8859-1"
# 476:charset=3Diso-8859-1">=0D<script =
#
# samples/easy_ham/1077.5967a2892063a3470f32596403b095aa
# 40:Content-Type: text/plain; charset=us-ascii
#
# samples/spam/0355.94ebf637e4bd3db8a81c8ce68ecf681d
# 28:Content-Type: text/plain; charset=us-ascii
# 92:Content-Type: text/html; charset=us-ascii
# 96:<META http-equiv=Content-Type content="text/html; charset=iso-8859-1">
#
# samples/easy_ham/0461.7609029b07acf65f40bd93882aa35887
# 31:Content-Type: TEXT/PLAIN; charset=ISO-8859-1
#
# samples/hard_ham/0054.a1ec171dcbc37d0b4f68e7e2074f33ca
# 12:Content-Type: text/html; charset=ISO-8859-1
#
# samples/hard_ham/0239.34e6b6125909c0d998370aacc82daefe
# 26:Content-Type: multipart/alternative; boundary="----------=_1033046883-23957-4";charset="iso-8859-1"
# 32:Content-Type: text/plain; charset="iso-8859-1"
# 321:Content-Type: text/html; charset="iso-8859-1"
#
# samples/hard_ham/0044.27a8944e81a2e9238f2de89eca51321d
# 19:Content-Type: text/html; charset=us-ascii
#
# samples/hard_ham/0050.055a745d0040ad87b4695a1f23502a81
# 15:Content-Type: text/plain; charset=ISO-8859-1
# 38:Content-Type: text/html; charset=ISO-8859-1
#
# samples/hard_ham/0035.4fe7648654fa3fa1ae5379894f00474f
# 12:Content-Type: text/html; charset=ISO-8859-1

# %%
_file = "./samples/easy_ham/0296.42216a75e0256510b216eaba6893d40d"

_message = None
with open(_file, mode="r") as file:
  _message = message_from_file(file)

# %% [markdown]
# charset指定されたファイルがあるのでそちらもケアする必要がある

# %%
_message.get_payload()
# Out:
# 'Of course, everyone knows that Owlman is a work of fuggin` genius\n\nJ\n\n\n\n\n> Hey, I met the wizard bloke from Owlman, who wants to touch me!!\n> \n> Dave\n\n\n\n------------------------ Yahoo! Groups Sponsor ---------------------~-->\n4 DVDs Free +s&p Join Now\nhttp://us.click.yahoo.com/pt6YBB/NXiEAA/MVfIAA/7gSolB/TM\n---------------------------------------------------------------------~->\n\nTo unsubscribe from this group, send an email to:\nforteana-unsubscribe@egroups.com\n\n \n\nYour use of Yahoo! Groups is subject to http://docs.yahoo.com/info/terms/ \n\n\n\n'

# %%
charset = _message.get_charsets()
_message.get_payload(decode=True).decode(charset[0])
# Out:
# 'Of course, everyone knows that Owlman is a work of fuggin` genius\n\nJ\n\n\n\n\n> Hey, I met the wizard bloke from Owlman, who wants to touch me!!\n> \n> Dave\n\n\n\n------------------------ Yahoo! Groups Sponsor ---------------------~-->\n4 DVDs Free +s&p Join Now\nhttp://us.click.yahoo.com/pt6YBB/NXiEAA/MVfIAA/7gSolB/TM\n---------------------------------------------------------------------~->\n\nTo unsubscribe from this group, send an email to:\nforteana-unsubscribe@egroups.com\n\n \n\nYour use of Yahoo! Groups is subject to http://docs.yahoo.com/info/terms/ \n\n\n\n'
